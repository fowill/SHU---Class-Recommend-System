# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as st
import seaborn as sns

#plt.rcParams['font.sans-serif'] = ['SimHei']  # 显示中文
sns.set_context("talk", font_scale=1)

# 设置画布
fig = plt.figure(figsize=(8, 8))  # 确定绘图区域尺寸
ax1 = fig.add_subplot(1, 1, 1)
x = np.arange(0.01, 20, 0.01) 

# 绘制gamma分布曲线
y1 = st.gamma.pdf(x, 1, scale=0.5)  # "α=1,β=2"
y2 = st.gamma.pdf(x, 2, scale=0.5)  # "α=2,β=2"
y3 = st.gamma.pdf(x, 3, scale=0.5)  # "α=3,β=2"
y4 = st.gamma.pdf(x, 4, scale=0.5)  # "α=5,β=1"
y5 = st.gamma.pdf(x, 5, scale=0.5)  # "α=9,β=0.5"

# 设置图例
ax1.plot(x, y1, label="α=1,β=0.5")
ax1.plot(x, y2, label="α=2,β=0.5")
ax1.plot(x, y3, label="α=3,β=0.5")
ax1.plot(x, y4, label="α=4,β=0.5")
ax1.plot(x, y5, label="α=5,β=0.5")

# 设置坐标轴标题
ax1.set_xlabel('x')
ax1.set_ylabel('p(x)')
ax1.set_title("Gamma")
ax1.legend(loc="best")

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as st
import seaborn as sns

#plt.rcParams['font.sans-serif'] = ['SimHei']  # 显示中文
sns.set_context("talk", font_scale=1)

# 设置画布
fig = plt.figure(figsize=(8, 8))  # 确定绘图区域尺寸
ax1 = fig.add_subplot(1, 1, 1)
x = np.arange(0.01, 20, 0.01) 

# 绘制gamma分布曲线
y1 = st.gamma.pdf(x, 1, scale=0.5)  # "α=1,β=2"
y2 = st.gamma.pdf(x, 2, scale=0.5)  # "α=2,β=2"
y3 = st.gamma.pdf(x, 3, scale=0.5)  # "α=3,β=2"
y4 = st.gamma.pdf(x, 4, scale=0.5)  # "α=5,β=1"
y5 = st.gamma.pdf(x, 5, scale=0.5)  # "α=9,β=0.5"

# 设置图例
ax1.plot(x, y1, label="α=1,β=0.5")
ax1.plot(x, y2, label="α=2,β=0.5")
ax1.plot(x, y3, label="α=3,β=0.5")
ax1.plot(x, y4, label="α=4,β=0.5")
ax1.plot(x, y5, label="α=5,β=0.5")

# 设置坐标轴标题
ax1.set_xlabel('x')
ax1.set_ylabel('p(x)')
ax1.set_title("Gamma")
ax1.legend(loc="best")

plt.show()

# %%
from scipy.special import factorial

Xs = np.linspace(0, 50, 51)

def PD(k, lmd):
    return np.power(lmd, k) * np.exp(-lmd) / factorial(k)

plt.figure(figsize=(10, 6))
plt.plot(Xs, PD(Xs, lmd=1), '--', label=rf'$\lambda=1$')
plt.plot(Xs, PD(Xs, lmd=5), '--', label=rf'$\lambda=5$')
plt.plot(Xs, PD(Xs, lmd=10), '--', label=rf'$\lambda=10$')
plt.plot(Xs, PD(Xs, lmd=15), '--', label=rf'$\lambda=15$')

plt.legend()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import math
 
 
def normal_distribution(x, mu, sigma):
    return np.exp( -1 * ( (x-mu) ** 2) / ( 2 * (sigma ** 2)) ) / (math.sqrt( 2 * np.pi ) * sigma)

mu, sigma = 2.75, 0.4
x = np.linspace( mu - 6 * sigma, mu + 6 * sigma, 100)
y = normal_distribution(x, mu, sigma)
plt.plot(x, y, 'r')
plt.show()

# %%
from scipy.special import factorial

Xs = np.linspace(0, 50, 51)

def PD(k, lmd):
    return np.power(lmd, k) * np.exp(-lmd) / factorial(k)

plt.figure(figsize=(10, 6))
plt.plot(Xs, PD(Xs, lmd=4), '--', label=rf'$\lambda=1$')
plt.plot(Xs, PD(Xs, lmd=5), '--', label=rf'$\lambda=5$')
plt.plot(Xs, PD(Xs, lmd=10), '--', label=rf'$\lambda=10$')
plt.plot(Xs, PD(Xs, lmd=15), '--', label=rf'$\lambda=15$')

plt.legend()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as st
import seaborn as sns

#plt.rcParams['font.sans-serif'] = ['SimHei']  # 显示中文
sns.set_context("talk", font_scale=1)

# 设置画布
fig = plt.figure(figsize=(8, 8))  # 确定绘图区域尺寸
ax1 = fig.add_subplot(1, 1, 1)
x = np.arange(3, 4, 0.01) 

# 绘制gamma分布曲线
y1 = 12.5*st.gamma.pdf(x, 1, scale=0.5)  # "α=1,β=2"
y2 = 12.5*st.gamma.pdf(x, 2, scale=0.5)  # "α=2,β=2"
y3 = 12.5*st.gamma.pdf(x, 3, scale=0.5)  # "α=3,β=2"

# 设置图例
ax1.plot(x, y1, label="α=1,β=0.5")
ax1.plot(x, y2, label="α=2,β=0.5")
ax1.plot(x, y3, label="α=3,β=0.5")

# 设置坐标轴标题
ax1.set_xlabel('x')
ax1.set_ylabel('p(x)')
ax1.set_title("Gamma")
ax1.legend(loc="best")

plt.show()

# %%
lambd = 2
x = np.arange(0,4,0.01)
y = 0.5*lambd*np.exp(-lambd*x)
plt.plot(x,y)
plt.title('Exponential:$\lambda$=%.2f' % lambd)
plt.xlabel('x')
plt.ylabel('Probability density')
plt.show()

# %%
x = np.arange(0,4,0.01)
y = 1 - np.exp(-lambd*x)
plt.plot(x,y)
plt.title('Exponential:$\lambda$=%.2f' % lambd)
plt.xlabel('x')
plt.ylabel('Probability density')
plt.show()

# %%
import numpy as np

ablity_ls = np.random.normal(7, 1, 10)
print(ablity_ls)
print(round(ablity_ls[1]))
# Out:
# [7.49264961 8.87167663 5.71882602 7.80771302 7.50704816 7.13493693
#  8.61128506 6.40624518 7.7681084  6.77180663]
# 9.0
